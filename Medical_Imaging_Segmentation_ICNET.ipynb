# %% [markdown]
# <a href="https://colab.research.google.com/github/nandinib1999/lungs-segmentation-ICNET/blob/master/Medical_Imaging_Segmentation_ICNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
import os
import sys
import random
import warnings
import zipfile
import numpy as np
import pandas as pd
import re

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dropout, Lambda, BatchNormalization, ZeroPadding2D, Conv2D, Conv2DTranspose
from tensorflow.keras.layers import concatenate, MaxPooling2D, Add, Activation, AveragePooling2D, UpSampling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K

import tensorflow as tf

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3

# %%
seed = 42
random.seed = seed
np.random.seed = seed

# %%
with zipfile.ZipFile('data.zip', 'r') as zip_ref:
    zip_ref.extractall()
    
extracted_contents = os.listdir()
print("Extracted contents:", extracted_contents)
# Out:
# Extracted contents: ['.ipynb_checkpoints', 'data', 'data.zip', 'Medical_Imaging_Segmentation_ICNET.ipynb']

# %%
zip_file_path = 'data/test.zip'
destination_folder = 'test_data'

# Unzip the data using Python code
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_folder)
    
extracted_contents = os.listdir(destination_folder)
print("Extracted contents:", extracted_contents)
# Out:
# Extracted contents: ['test']

# %%
zip_file_path = 'data/train.zip'
destination_folder = 'train_data'

# Unzip the data using Python code
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_folder)
    
extracted_contents = os.listdir(destination_folder)
print("Extracted contents:", extracted_contents)
# Out:
# Extracted contents: ['train']

# %%
TRAIN_PATH = 'train_data/train'
TEST_PATH = 'test_data/test'


# Get train and test IDs
train_ids = os.listdir(TRAIN_PATH)
test_ids = os.listdir(TEST_PATH)

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
print('Getting and resizing train images and masks ... ')
# Out:
# Getting and resizing train images and masks ...

# %%
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    print(id_)
    if id_ != ".ipynb_checkpoints":
        path = os.path.join(TRAIN_PATH, id_)
        img = imread(os.path.join(path, 'images', id_+'.png'))
        img = np.expand_dims(resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True), axis=-1)
        print(img.shape)
        X_train[n] = img

        mask_ = imread(path + '/mask/' + id_+'.png')
        print(mask_.shape)
        
        if len(mask_.shape) == 3:
            # If the mask has multiple channels, select the first channel
            mask_ = mask_[:, :, 0]
        
        mask_ = resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

        # Convert to binary mask (True for non-zero values, False for zero)
        mask = mask_ > 0

        # Expand dimensions to match Y_train shape
        mask = np.expand_dims(mask, axis=-1)

        Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = os.path.join(TEST_PATH, id_)
    img = imread(os.path.join(path, 'images', id_+'.png'))#[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = np.expand_dims(resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True), axis=-1)
    X_test[n] = img

print('Done!')
# Out:
#   7%|██████                                                                             | 3/41 [00:00<00:01, 29.86it/s]
# IM-0001-0001
# (256, 256, 1)
# (256, 256, 2)
# IM-0003-0001
# (256, 256, 1)
# (256, 256)
# IM-0005-0001
# (256, 256, 1)
# (256, 256)
# IM-0006-0001
# (256, 256, 1)
# (256, 256)
# IM-0007-0001
# (256, 256, 1)
# (256, 256)
# IM-0009-0001
#  22%|██████████████████▏                                                                | 9/41 [00:00<00:01, 22.31it/s]
# (256, 256, 1)
# (256, 256)
# IM-0010-0001
# (256, 256, 1)
# (256, 256)
# IM-0011-0001
# (256, 256, 1)
# (256, 256)
# IM-0011-0001-0001
# (256, 256, 1)
# (256, 256)
# IM-0011-0001-0002
# (256, 256, 1)
#  37%|██████████████████████████████                                                    | 15/41 [00:00<00:01, 24.25it/s]
# (256, 256)
# IM-0013-0001
# (256, 256, 1)
# (256, 256)
# IM-0015-0001
# (256, 256, 1)
# (256, 256)
# IM-0016-0001
# (256, 256, 1)
# (256, 256)
# IM-0017-0001
# (256, 256, 1)
# (256, 256)
# IM-0019-0001
# (256, 256, 1)
# (256, 256)
#  44%|████████████████████████████████████                                              | 18/41 [00:00<00:00, 23.78it/s]
# IM-0021-0001
# (256, 256, 1)
# (256, 256)
# IM-0022-0001
# (256, 256, 1)
# (256, 256)
# IM-0023-0001
# (256, 256, 1)
# (256, 256)
# IM-0025-0001
# (256, 256, 1)
# (256, 256)
# IM-0027-0001
# (256, 256, 1)
#  51%|██████████████████████████████████████████                                        | 21/41 [00:00<00:00, 24.90it/s]
# (256, 256)
# IM-0028-0001
# (256, 256, 1)
# (256, 256)
# IM-0029-0001
# (256, 256, 1)
# (256, 256)
# IM-0030-0001
# (256, 256, 1)
# (256, 256)
# IM-0031-0001
# (256, 256, 1)
# (256, 256)
#  66%|██████████████████████████████████████████████████████                            | 27/41 [00:01<00:00, 21.69it/s]
# IM-0033-0001
# (256, 256, 1)
# (256, 256)
# IM-0033-0001-0001
# (256, 256, 1)
# (256, 256)
# IM-0033-0001-0002
# (256, 256, 1)
# (256, 256)
# IM-0035-0001
# (256, 256, 1)
#  73%|████████████████████████████████████████████████████████████                      | 30/41 [00:01<00:00, 19.93it/s]
# (256, 256)
# IM-0036-0001
# (256, 256, 1)
# (256, 256)
# IM-0037-0001
# (256, 256, 1)
# (256, 256)
# IM-0039-0001
# (256, 256, 1)
# (256, 256)
# IM-0041-0001
# (256, 256, 1)
# (256, 256)
#  88%|████████████████████████████████████████████████████████████████████████          | 36/41 [00:01<00:00, 21.11it/s]
# IM-0043-0001
# (256, 256, 1)
# (256, 256)
# IM-0045-0001
# (256, 256, 1)
# (256, 256)
# IM-0046-0001
# (256, 256, 1)
# (256, 256)
# IM-0049-0001
# (256, 256, 1)
# (256, 256)
# IM-0050-0001
# (256, 256, 1)
#  95%|██████████████████████████████████████████████████████████████████████████████    | 39/41 [00:01<00:00, 21.67it/s]
# (256, 256)
# IM-0059-0001
# (256, 256, 1)
# (256, 256)
# IM-0061-0001
# (256, 256, 1)
# (256, 256)
# IM-0063-0001
# (256, 256, 1)
# (256, 256)
# IM-0065-0001
# (256, 256, 1)
# (256, 256)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [00:01<00:00, 22.24it/s]
# Getting and resizing test images ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 48.80it/s]
# Done!

# %%
ix = random.randint(0, len(train_ids))
imshow(np.squeeze(X_train[ix]))
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
def build_bn(width, height, n_classes, weights_path=None, train=False):
    inp = Input(shape=(height, width, 1))
    x = Lambda(lambda x: (x - 127.5)/255.0)(inp)

    # (1/2)
    y = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(int(x.shape[1])//2, int(x.shape[2])//2)), name='data_sub2')(x)
    y = Conv2D(32, 3, strides=2, padding='same', activation='relu', name='conv1_1_3x3_s2')(y)
    y = BatchNormalization(name='conv1_1_3x3_s2_bn')(y)
    y = Conv2D(32, 3, padding='same', activation='relu', name='conv1_2_3x3')(y)
    y = BatchNormalization(name='conv1_2_3x3_s2_bn')(y)
    y = Conv2D(64, 3, padding='same', activation='relu', name='conv1_3_3x3')(y)
    y = BatchNormalization(name='conv1_3_3x3_bn')(y)
    y_ = MaxPooling2D(pool_size=3, strides=2, name='pool1_3x3_s2')(y)
    
    y = Conv2D(128, 1, name='conv2_1_1x1_proj')(y_)
    y = BatchNormalization(name='conv2_1_1x1_proj_bn')(y)
    y_ = Conv2D(32, 1, activation='relu', name='conv2_1_1x1_reduce')(y_)
    y_ = BatchNormalization(name='conv2_1_1x1_reduce_bn')(y_)
    y_ = ZeroPadding2D(name='padding1')(y_)
    y_ = Conv2D(32, 3, activation='relu', name='conv2_1_3x3')(y_)
    y_ = BatchNormalization(name='conv2_1_3x3_bn')(y_)
    y_ = Conv2D(128, 1, name='conv2_1_1x1_increase')(y_)
    y_ = BatchNormalization(name='conv2_1_1x1_increase_bn')(y_)
    y = Add(name='conv2_1')([y,y_])
    y_ = Activation('relu', name='conv2_1/relu')(y)

    y = Conv2D(32, 1, activation='relu', name='conv2_2_1x1_reduce')(y_)
    y = BatchNormalization(name='conv2_2_1x1_reduce_bn')(y)
    y = ZeroPadding2D(name='padding2')(y)
    y = Conv2D(32, 3, activation='relu', name='conv2_2_3x3')(y)
    y = BatchNormalization(name='conv2_2_3x3_bn')(y)
    y = Conv2D(128, 1, name='conv2_2_1x1_increase')(y)
    y = BatchNormalization(name='conv2_2_1x1_increase_bn')(y)
    y = Add(name='conv2_2')([y,y_])
    y_ = Activation('relu', name='conv2_2/relu')(y)

    y = Conv2D(32, 1, activation='relu', name='conv2_3_1x1_reduce')(y_)
    y = BatchNormalization(name='conv2_3_1x1_reduce_bn')(y)
    y = ZeroPadding2D(name='padding3')(y)
    y = Conv2D(32, 3, activation='relu', name='conv2_3_3x3')(y)
    y = BatchNormalization(name='conv2_3_3x3_bn')(y)
    y = Conv2D(128, 1, name='conv2_3_1x1_increase')(y)
    y = BatchNormalization(name='conv2_3_1x1_increase_bn')(y)
    y = Add(name='conv2_3')([y,y_])
    y_ = Activation('relu', name='conv2_3/relu')(y)

    y = Conv2D(256, 1, strides=2, name='conv3_1_1x1_proj')(y_)
    y = BatchNormalization(name='conv3_1_1x1_proj_bn')(y)
    y_ = Conv2D(64, 1, strides=2, activation='relu', name='conv3_1_1x1_reduce')(y_)
    y_ = BatchNormalization(name='conv3_1_1x1_reduce_bn')(y_) 
    y_ = ZeroPadding2D(name='padding4')(y_)
    y_ = Conv2D(64, 3, activation='relu', name='conv3_1_3x3')(y_)
    y_ = BatchNormalization(name='conv3_1_3x3_bn')(y_)
    y_ = Conv2D(256, 1, name='conv3_1_1x1_increase')(y_)
    y_ = BatchNormalization(name='conv3_1_1x1_increase_bn')(y_)
    y = Add(name='conv3_1')([y,y_])
    z = Activation('relu', name='conv3_1/relu')(y)

    # (1/4)
    y_ = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(int(x.shape[1])//2, int(x.shape[2])//2)), name='conv3_1_sub4')(z)
    y = Conv2D(64, 1, activation='relu', name='conv3_2_1x1_reduce')(y_)
    y = BatchNormalization(name='conv3_2_1x1_reduce_bn')(y)
    y = ZeroPadding2D(name='padding5')(y)
    y = Conv2D(64, 3, activation='relu', name='conv3_2_3x3')(y)
    y = BatchNormalization(name='conv3_2_3x3_bn')(y)
    y = Conv2D(256, 1, name='conv3_2_1x1_increase')(y)
    y = BatchNormalization(name='conv3_2_1x1_increase_bn')(y)
    y = Add(name='conv3_2')([y,y_])
    y_ = Activation('relu', name='conv3_2/relu')(y)

    y = Conv2D(64, 1, activation='relu', name='conv3_3_1x1_reduce')(y_)
    y = BatchNormalization(name='conv3_3_1x1_reduce_bn')(y)
    y = ZeroPadding2D(name='padding6')(y)
    y = Conv2D(64, 3, activation='relu', name='conv3_3_3x3')(y)
    y = BatchNormalization(name='conv3_3_3x3_bn')(y)
    y = Conv2D(256, 1, name='conv3_3_1x1_increase')(y)
    y = BatchNormalization(name='conv3_3_1x1_increase_bn')(y)
    y = Add(name='conv3_3')([y,y_])
    y_ = Activation('relu', name='conv3_3/relu')(y)

    y = Conv2D(64, 1, activation='relu', name='conv3_4_1x1_reduce')(y_)
    y = BatchNormalization(name='conv3_4_1x1_reduce_bn')(y)
    y = ZeroPadding2D(name='padding7')(y)
    y = Conv2D(64, 3, activation='relu', name='conv3_4_3x3')(y)
    y = BatchNormalization(name='conv3_4_3x3_bn')(y)
    y = Conv2D(256, 1, name='conv3_4_1x1_increase')(y)
    y = BatchNormalization(name='conv3_4_1x1_increase_bn')(y)
    y = Add(name='conv3_4')([y,y_])
    y_ = Activation('relu', name='conv3_4/relu')(y)

    y = Conv2D(512, 1, name='conv4_1_1x1_proj')(y_)
    y = BatchNormalization(name='conv4_1_1x1_proj_bn')(y)
    y_ = Conv2D(128, 1, activation='relu', name='conv4_1_1x1_reduce')(y_)
    y_ = BatchNormalization(name='conv4_1_1x1_reduce_bn')(y_)
    y_ = ZeroPadding2D(padding=2, name='padding8')(y_)
    y_ = Conv2D(128, 3, dilation_rate=2, activation='relu', name='conv4_1_3x3')(y_)
    y_ = BatchNormalization(name='conv4_1_3x3_bn')(y_)
    y_ = Conv2D(512, 1, name='conv4_1_1x1_increase')(y_)
    y_ = BatchNormalization(name='conv4_1_1x1_increase_bn')(y_)
    y = Add(name='conv4_1')([y,y_])
    y_ = Activation('relu', name='conv4_1/relu')(y)

    y = Conv2D(128, 1, activation='relu', name='conv4_2_1x1_reduce')(y_)
    y = BatchNormalization(name='conv4_2_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=2, name='padding9')(y)
    y = Conv2D(128, 3, dilation_rate=2, activation='relu', name='conv4_2_3x3')(y)
    y = BatchNormalization(name='conv4_2_3x3_bn')(y)
    y = Conv2D(512, 1, name='conv4_2_1x1_increase')(y)
    y = BatchNormalization(name='conv4_2_1x1_increase_bn')(y)
    y = Add(name='conv4_2')([y,y_])
    y_ = Activation('relu', name='conv4_2/relu')(y)

    y = Conv2D(128, 1, activation='relu', name='conv4_3_1x1_reduce')(y_)
    y = BatchNormalization(name='conv4_3_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=2, name='padding10')(y)
    y = Conv2D(128, 3, dilation_rate=2, activation='relu', name='conv4_3_3x3')(y)
    y = BatchNormalization(name='conv4_3_3x3_bn')(y)
    y = Conv2D(512, 1, name='conv4_3_1x1_increase')(y)
    y = BatchNormalization(name='conv4_3_1x1_increase_bn')(y)
    y = Add(name='conv4_3')([y,y_])
    y_ = Activation('relu', name='conv4_3/relu')(y)

    y = Conv2D(128, 1, activation='relu', name='conv4_4_1x1_reduce')(y_)
    y = BatchNormalization(name='conv4_4_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=2, name='padding11')(y)
    y = Conv2D(128, 3, dilation_rate=2, activation='relu', name='conv4_4_3x3')(y)
    y = BatchNormalization(name='conv4_4_3x3_bn')(y)
    y = Conv2D(512, 1, name='conv4_4_1x1_increase')(y)
    y = BatchNormalization(name='conv4_4_1x1_increase_bn')(y)
    y = Add(name='conv4_4')([y,y_])
    y_ = Activation('relu', name='conv4_4/relu')(y)

    y = Conv2D(128, 1, activation='relu', name='conv4_5_1x1_reduce')(y_)
    y = BatchNormalization(name='conv4_5_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=2, name='padding12')(y)
    y = Conv2D(128, 3, dilation_rate=2, activation='relu', name='conv4_5_3x3')(y)
    y = BatchNormalization(name='conv4_5_3x3_bn')(y)
    y = Conv2D(512, 1, name='conv4_5_1x1_increase')(y)
    y = BatchNormalization(name='conv4_5_1x1_increase_bn')(y)
    y = Add(name='conv4_5')([y,y_])
    y_ = Activation('relu', name='conv4_5/relu')(y)

    y = Conv2D(128, 1, activation='relu', name='conv4_6_1x1_reduce')(y_)
    y = BatchNormalization(name='conv4_6_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=2, name='padding13')(y)
    y = Conv2D(128, 3, dilation_rate=2, activation='relu', name='conv4_6_3x3')(y)
    y = BatchNormalization(name='conv4_6_3x3_bn')(y)
    y = Conv2D(512, 1, name='conv4_6_1x1_increase')(y)
    y = BatchNormalization(name='conv4_6_1x1_increase_bn')(y)
    y = Add(name='conv4_6')([y,y_])
    y = Activation('relu', name='conv4_6/relu')(y)

    y_ = Conv2D(1024, 1, name='conv5_1_1x1_proj')(y)
    y_ = BatchNormalization(name='conv5_1_1x1_proj_bn')(y_)
    y = Conv2D(256, 1, activation='relu', name='conv5_1_1x1_reduce')(y)
    y = BatchNormalization(name='conv5_1_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=4, name='padding14')(y)
    y = Conv2D(256, 3, dilation_rate=4, activation='relu', name='conv5_1_3x3')(y)
    y = BatchNormalization(name='conv5_1_3x3_bn')(y)
    y = Conv2D(1024, 1, name='conv5_1_1x1_increase')(y)
    y = BatchNormalization(name='conv5_1_1x1_increase_bn')(y)
    y = Add(name='conv5_1')([y,y_])
    y_ = Activation('relu', name='conv5_1/relu')(y)

    y = Conv2D(256, 1, activation='relu', name='conv5_2_1x1_reduce')(y_)
    y = BatchNormalization(name='conv5_2_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=4, name='padding15')(y)
    y = Conv2D(256, 3, dilation_rate=4, activation='relu', name='conv5_2_3x3')(y)
    y = BatchNormalization(name='conv5_2_3x3_bn')(y)
    y = Conv2D(1024, 1, name='conv5_2_1x1_increase')(y)
    y = BatchNormalization(name='conv5_2_1x1_increase_bn')(y)
    y = Add(name='conv5_2')([y,y_])
    y_ = Activation('relu', name='conv5_2/relu')(y)

    y = Conv2D(256, 1, activation='relu', name='conv5_3_1x1_reduce')(y_)
    y = BatchNormalization(name='conv5_3_1x1_reduce_bn')(y)
    y = ZeroPadding2D(padding=4, name='padding16')(y)
    y = Conv2D(256, 3, dilation_rate=4, activation='relu', name='conv5_3_3x3')(y)
    y = BatchNormalization(name='conv5_3_3x3_bn')(y)
    y = Conv2D(1024, 1, name='conv5_3_1x1_increase')(y)
    y = BatchNormalization(name='conv5_3_1x1_increase_bn')(y)
    y = Add(name='conv5_3')([y,y_])
    y = Activation('relu', name='conv5_3/relu')(y)

    h, w = y.shape[1:3].as_list()
    pool1 = AveragePooling2D(pool_size=(h,w), strides=(h,w), name='conv5_3_pool1')(y)
    pool1 = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(h,w)), name='conv5_3_pool1_interp')(pool1)
    pool2 = AveragePooling2D(pool_size=(h/2,w/2), strides=(h//2,w//2), name='conv5_3_pool2')(y)
    pool2 = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(h,w)), name='conv5_3_pool2_interp')(pool2)
    pool3 = AveragePooling2D(pool_size=(h/3,w/3), strides=(h//3,w//3), name='conv5_3_pool3')(y)
    pool3 = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(h,w)), name='conv5_3_pool3_interp')(pool3)
    pool6 = AveragePooling2D(pool_size=(h/4,w/4), strides=(h//4,w//4), name='conv5_3_pool6')(y)
    pool6 = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(h,w)), name='conv5_3_pool6_interp')(pool6)

    y = Add(name='conv5_3_sum')([y, pool1, pool2, pool3, pool6])
    y = Conv2D(256, 1, activation='relu', name='conv5_4_k1')(y)
    y = BatchNormalization(name='conv5_4_k1_bn')(y)
    aux_1 = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(int(x.shape[1])*2, int(x.shape[2])*2)), name='conv5_4_interp')(y)
    y = ZeroPadding2D(padding=2, name='padding17')(aux_1)
    y = Conv2D(128, 3, dilation_rate=2, name='conv_sub4')(y)
    y = BatchNormalization(name='conv_sub4_bn')(y)
    y_ = Conv2D(128, 1, name='conv3_1_sub2_proj')(z)
    y_ = BatchNormalization(name='conv3_1_sub2_proj_bn')(y_)
    y = Add(name='sub24_sum')([y,y_])
    y = Activation('relu', name='sub24_sum/relu')(y)

    aux_2 = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(int(x.shape[1])*2, int(x.shape[2])*2)), name='sub24_sum_interp')(y)
    y = ZeroPadding2D(padding=2, name='padding18')(aux_2)
    y_ = Conv2D(128, 3, dilation_rate=2, name='conv_sub2')(y)
    y_ = BatchNormalization(name='conv_sub2_bn')(y_)

    # (1)
    y = Conv2D(32, 3, strides=2, padding='same', activation='relu', name='conv1_sub1')(x)
    y = BatchNormalization(name='conv1_sub1_bn')(y)
    y = Conv2D(32, 3, strides=2, padding='same', activation='relu', name='conv2_sub1')(y)
    y = BatchNormalization(name='conv2_sub1_bn')(y)
    y = Conv2D(64, 3, strides=2, padding='same', activation='relu', name='conv3_sub1')(y)
    y = BatchNormalization(name='conv3_sub1_bn')(y)
    y = Conv2D(128, 1, name='conv3_sub1_proj')(y)
    y = BatchNormalization(name='conv3_sub1_proj_bn')(y)

    y = Add(name='sub12_sum')([y,y_])
    y = Activation('relu', name='sub12_sum/relu')(y)
    y = Lambda(lambda x: tf.compat.v1.image.resize_bilinear(x, size=(int(x.shape[1])*2, int(x.shape[2])*2)), name='sub12_sum_interp')(y)
    y = UpSampling2D(size=(4,4))(y)
    out = Conv2D(n_classes, 1, activation='sigmoid', name='conv6_cls')(y)

    if train:
        aux_1 = Conv2D(n_classes, 1, activation='sigmoid', name='sub4_out')(aux_1)
        aux_2 = Conv2D(n_classes, 1, activation='sigmoid', name='sub24_out')(aux_2)
        model = Model(inputs=inp, outputs=[out, aux_2, aux_1])
    else:
        model = Model(inputs=inp, outputs=out)
        
    if weights_path is not None:
        model.load_weights(weights_path, by_name=True)
    return model

# %%
model = build_bn(width = 256, height = 256, n_classes = 1, train=False)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  lambda (Lambda)             (None, 256, 256, 1)          0         ['input_1[0][0]']
#
#  data_sub2 (Lambda)          (None, 128, 128, 1)          0         ['lambda[0][0]']
#
#  conv1_1_3x3_s2 (Conv2D)     (None, 64, 64, 32)           320       ['data_sub2[0][0]']
#
#  conv1_1_3x3_s2_bn (BatchNo  (None, 64, 64, 32)           128       ['conv1_1_3x3_s2[0][0]']
#  rmalization)
#
#  conv1_2_3x3 (Conv2D)        (None, 64, 64, 32)           9248      ['conv1_1_3x3_s2_bn[0][0]']
#
#  conv1_2_3x3_s2_bn (BatchNo  (None, 64, 64, 32)           128       ['conv1_2_3x3[0][0]']
#  rmalization)
#
#  conv1_3_3x3 (Conv2D)        (None, 64, 64, 64)           18496     ['conv1_2_3x3_s2_bn[0][0]']
#
#  conv1_3_3x3_bn (BatchNorma  (None, 64, 64, 64)           256       ['conv1_3_3x3[0][0]']
#  lization)
#
#  pool1_3x3_s2 (MaxPooling2D  (None, 31, 31, 64)           0         ['conv1_3_3x3_bn[0][0]']
#  )
#
#  conv2_1_1x1_reduce (Conv2D  (None, 31, 31, 32)           2080      ['pool1_3x3_s2[0][0]']
#  )
#
#  conv2_1_1x1_reduce_bn (Bat  (None, 31, 31, 32)           128       ['conv2_1_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding1 (ZeroPadding2D)    (None, 33, 33, 32)           0         ['conv2_1_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv2_1_3x3 (Conv2D)        (None, 31, 31, 32)           9248      ['padding1[0][0]']
#
#  conv2_1_3x3_bn (BatchNorma  (None, 31, 31, 32)           128       ['conv2_1_3x3[0][0]']
#  lization)
#
#  conv2_1_1x1_proj (Conv2D)   (None, 31, 31, 128)          8320      ['pool1_3x3_s2[0][0]']
#
#  conv2_1_1x1_increase (Conv  (None, 31, 31, 128)          4224      ['conv2_1_3x3_bn[0][0]']
#  2D)
#
#  conv2_1_1x1_proj_bn (Batch  (None, 31, 31, 128)          512       ['conv2_1_1x1_proj[0][0]']
#  Normalization)
#
#  conv2_1_1x1_increase_bn (B  (None, 31, 31, 128)          512       ['conv2_1_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv2_1 (Add)               (None, 31, 31, 128)          0         ['conv2_1_1x1_proj_bn[0][0]',
#                                                                      'conv2_1_1x1_increase_bn[0][0
#                                                                     ]']
#
#  conv2_1/relu (Activation)   (None, 31, 31, 128)          0         ['conv2_1[0][0]']
#
#  conv2_2_1x1_reduce (Conv2D  (None, 31, 31, 32)           4128      ['conv2_1/relu[0][0]']
#  )
#
#  conv2_2_1x1_reduce_bn (Bat  (None, 31, 31, 32)           128       ['conv2_2_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding2 (ZeroPadding2D)    (None, 33, 33, 32)           0         ['conv2_2_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv2_2_3x3 (Conv2D)        (None, 31, 31, 32)           9248      ['padding2[0][0]']
#
#  conv2_2_3x3_bn (BatchNorma  (None, 31, 31, 32)           128       ['conv2_2_3x3[0][0]']
#  lization)
#
#  conv2_2_1x1_increase (Conv  (None, 31, 31, 128)          4224      ['conv2_2_3x3_bn[0][0]']
#  2D)
#
#  conv2_2_1x1_increase_bn (B  (None, 31, 31, 128)          512       ['conv2_2_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv2_2 (Add)               (None, 31, 31, 128)          0         ['conv2_2_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv2_1/relu[0][0]']
#
#  conv2_2/relu (Activation)   (None, 31, 31, 128)          0         ['conv2_2[0][0]']
#
#  conv2_3_1x1_reduce (Conv2D  (None, 31, 31, 32)           4128      ['conv2_2/relu[0][0]']
#  )
#
#  conv2_3_1x1_reduce_bn (Bat  (None, 31, 31, 32)           128       ['conv2_3_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding3 (ZeroPadding2D)    (None, 33, 33, 32)           0         ['conv2_3_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv2_3_3x3 (Conv2D)        (None, 31, 31, 32)           9248      ['padding3[0][0]']
#
#  conv2_3_3x3_bn (BatchNorma  (None, 31, 31, 32)           128       ['conv2_3_3x3[0][0]']
#  lization)
#
#  conv2_3_1x1_increase (Conv  (None, 31, 31, 128)          4224      ['conv2_3_3x3_bn[0][0]']
#  2D)
#
#  conv2_3_1x1_increase_bn (B  (None, 31, 31, 128)          512       ['conv2_3_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv2_3 (Add)               (None, 31, 31, 128)          0         ['conv2_3_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv2_2/relu[0][0]']
#
#  conv2_3/relu (Activation)   (None, 31, 31, 128)          0         ['conv2_3[0][0]']
#
#  conv3_1_1x1_reduce (Conv2D  (None, 16, 16, 64)           8256      ['conv2_3/relu[0][0]']
#  )
#
#  conv3_1_1x1_reduce_bn (Bat  (None, 16, 16, 64)           256       ['conv3_1_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding4 (ZeroPadding2D)    (None, 18, 18, 64)           0         ['conv3_1_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv3_1_3x3 (Conv2D)        (None, 16, 16, 64)           36928     ['padding4[0][0]']
#
#  conv3_1_3x3_bn (BatchNorma  (None, 16, 16, 64)           256       ['conv3_1_3x3[0][0]']
#  lization)
#
#  conv3_1_1x1_proj (Conv2D)   (None, 16, 16, 256)          33024     ['conv2_3/relu[0][0]']
#
#  conv3_1_1x1_increase (Conv  (None, 16, 16, 256)          16640     ['conv3_1_3x3_bn[0][0]']
#  2D)
#
#  conv3_1_1x1_proj_bn (Batch  (None, 16, 16, 256)          1024      ['conv3_1_1x1_proj[0][0]']
#  Normalization)
#
#  conv3_1_1x1_increase_bn (B  (None, 16, 16, 256)          1024      ['conv3_1_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv3_1 (Add)               (None, 16, 16, 256)          0         ['conv3_1_1x1_proj_bn[0][0]',
#                                                                      'conv3_1_1x1_increase_bn[0][0
#                                                                     ]']
#
#  conv3_1/relu (Activation)   (None, 16, 16, 256)          0         ['conv3_1[0][0]']
#
#  conv3_1_sub4 (Lambda)       (None, 8, 8, 256)            0         ['conv3_1/relu[0][0]']
#
#  conv3_2_1x1_reduce (Conv2D  (None, 8, 8, 64)             16448     ['conv3_1_sub4[0][0]']
#  )
#
#  conv3_2_1x1_reduce_bn (Bat  (None, 8, 8, 64)             256       ['conv3_2_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding5 (ZeroPadding2D)    (None, 10, 10, 64)           0         ['conv3_2_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv3_2_3x3 (Conv2D)        (None, 8, 8, 64)             36928     ['padding5[0][0]']
#
#  conv3_2_3x3_bn (BatchNorma  (None, 8, 8, 64)             256       ['conv3_2_3x3[0][0]']
#  lization)
#
#  conv3_2_1x1_increase (Conv  (None, 8, 8, 256)            16640     ['conv3_2_3x3_bn[0][0]']
#  2D)
#
#  conv3_2_1x1_increase_bn (B  (None, 8, 8, 256)            1024      ['conv3_2_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv3_2 (Add)               (None, 8, 8, 256)            0         ['conv3_2_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv3_1_sub4[0][0]']
#
#  conv3_2/relu (Activation)   (None, 8, 8, 256)            0         ['conv3_2[0][0]']
#
#  conv3_3_1x1_reduce (Conv2D  (None, 8, 8, 64)             16448     ['conv3_2/relu[0][0]']
#  )
#
#  conv3_3_1x1_reduce_bn (Bat  (None, 8, 8, 64)             256       ['conv3_3_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding6 (ZeroPadding2D)    (None, 10, 10, 64)           0         ['conv3_3_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv3_3_3x3 (Conv2D)        (None, 8, 8, 64)             36928     ['padding6[0][0]']
#
#  conv3_3_3x3_bn (BatchNorma  (None, 8, 8, 64)             256       ['conv3_3_3x3[0][0]']
#  lization)
#
#  conv3_3_1x1_increase (Conv  (None, 8, 8, 256)            16640     ['conv3_3_3x3_bn[0][0]']
#  2D)
#
#  conv3_3_1x1_increase_bn (B  (None, 8, 8, 256)            1024      ['conv3_3_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv3_3 (Add)               (None, 8, 8, 256)            0         ['conv3_3_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv3_2/relu[0][0]']
#
#  conv3_3/relu (Activation)   (None, 8, 8, 256)            0         ['conv3_3[0][0]']
#
#  conv3_4_1x1_reduce (Conv2D  (None, 8, 8, 64)             16448     ['conv3_3/relu[0][0]']
#  )
#
#  conv3_4_1x1_reduce_bn (Bat  (None, 8, 8, 64)             256       ['conv3_4_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding7 (ZeroPadding2D)    (None, 10, 10, 64)           0         ['conv3_4_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv3_4_3x3 (Conv2D)        (None, 8, 8, 64)             36928     ['padding7[0][0]']
#
#  conv3_4_3x3_bn (BatchNorma  (None, 8, 8, 64)             256       ['conv3_4_3x3[0][0]']
#  lization)
#
#  conv3_4_1x1_increase (Conv  (None, 8, 8, 256)            16640     ['conv3_4_3x3_bn[0][0]']
#  2D)
#
#  conv3_4_1x1_increase_bn (B  (None, 8, 8, 256)            1024      ['conv3_4_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv3_4 (Add)               (None, 8, 8, 256)            0         ['conv3_4_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv3_3/relu[0][0]']
#
#  conv3_4/relu (Activation)   (None, 8, 8, 256)            0         ['conv3_4[0][0]']
#
#  conv4_1_1x1_reduce (Conv2D  (None, 8, 8, 128)            32896     ['conv3_4/relu[0][0]']
#  )
#
#  conv4_1_1x1_reduce_bn (Bat  (None, 8, 8, 128)            512       ['conv4_1_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding8 (ZeroPadding2D)    (None, 12, 12, 128)          0         ['conv4_1_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv4_1_3x3 (Conv2D)        (None, 8, 8, 128)            147584    ['padding8[0][0]']
#
#  conv4_1_3x3_bn (BatchNorma  (None, 8, 8, 128)            512       ['conv4_1_3x3[0][0]']
#  lization)
#
#  conv4_1_1x1_proj (Conv2D)   (None, 8, 8, 512)            131584    ['conv3_4/relu[0][0]']
#
#  conv4_1_1x1_increase (Conv  (None, 8, 8, 512)            66048     ['conv4_1_3x3_bn[0][0]']
#  2D)
#
#  conv4_1_1x1_proj_bn (Batch  (None, 8, 8, 512)            2048      ['conv4_1_1x1_proj[0][0]']
#  Normalization)
#
#  conv4_1_1x1_increase_bn (B  (None, 8, 8, 512)            2048      ['conv4_1_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv4_1 (Add)               (None, 8, 8, 512)            0         ['conv4_1_1x1_proj_bn[0][0]',
#                                                                      'conv4_1_1x1_increase_bn[0][0
#                                                                     ]']
#
#  conv4_1/relu (Activation)   (None, 8, 8, 512)            0         ['conv4_1[0][0]']
#
#  conv4_2_1x1_reduce (Conv2D  (None, 8, 8, 128)            65664     ['conv4_1/relu[0][0]']
#  )
#
#  conv4_2_1x1_reduce_bn (Bat  (None, 8, 8, 128)            512       ['conv4_2_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding9 (ZeroPadding2D)    (None, 12, 12, 128)          0         ['conv4_2_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv4_2_3x3 (Conv2D)        (None, 8, 8, 128)            147584    ['padding9[0][0]']
#
#  conv4_2_3x3_bn (BatchNorma  (None, 8, 8, 128)            512       ['conv4_2_3x3[0][0]']
#  lization)
#
#  conv4_2_1x1_increase (Conv  (None, 8, 8, 512)            66048     ['conv4_2_3x3_bn[0][0]']
#  2D)
#
#  conv4_2_1x1_increase_bn (B  (None, 8, 8, 512)            2048      ['conv4_2_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv4_2 (Add)               (None, 8, 8, 512)            0         ['conv4_2_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv4_1/relu[0][0]']
#
#  conv4_2/relu (Activation)   (None, 8, 8, 512)            0         ['conv4_2[0][0]']
#
#  conv4_3_1x1_reduce (Conv2D  (None, 8, 8, 128)            65664     ['conv4_2/relu[0][0]']
#  )
#
#  conv4_3_1x1_reduce_bn (Bat  (None, 8, 8, 128)            512       ['conv4_3_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding10 (ZeroPadding2D)   (None, 12, 12, 128)          0         ['conv4_3_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv4_3_3x3 (Conv2D)        (None, 8, 8, 128)            147584    ['padding10[0][0]']
#
#  conv4_3_3x3_bn (BatchNorma  (None, 8, 8, 128)            512       ['conv4_3_3x3[0][0]']
#  lization)
#
#  conv4_3_1x1_increase (Conv  (None, 8, 8, 512)            66048     ['conv4_3_3x3_bn[0][0]']
#  2D)
#
#  conv4_3_1x1_increase_bn (B  (None, 8, 8, 512)            2048      ['conv4_3_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv4_3 (Add)               (None, 8, 8, 512)            0         ['conv4_3_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv4_2/relu[0][0]']
#
#  conv4_3/relu (Activation)   (None, 8, 8, 512)            0         ['conv4_3[0][0]']
#
#  conv4_4_1x1_reduce (Conv2D  (None, 8, 8, 128)            65664     ['conv4_3/relu[0][0]']
#  )
#
#  conv4_4_1x1_reduce_bn (Bat  (None, 8, 8, 128)            512       ['conv4_4_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding11 (ZeroPadding2D)   (None, 12, 12, 128)          0         ['conv4_4_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv4_4_3x3 (Conv2D)        (None, 8, 8, 128)            147584    ['padding11[0][0]']
#
#  conv4_4_3x3_bn (BatchNorma  (None, 8, 8, 128)            512       ['conv4_4_3x3[0][0]']
#  lization)
#
#  conv4_4_1x1_increase (Conv  (None, 8, 8, 512)            66048     ['conv4_4_3x3_bn[0][0]']
#  2D)
#
#  conv4_4_1x1_increase_bn (B  (None, 8, 8, 512)            2048      ['conv4_4_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv4_4 (Add)               (None, 8, 8, 512)            0         ['conv4_4_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv4_3/relu[0][0]']
#
#  conv4_4/relu (Activation)   (None, 8, 8, 512)            0         ['conv4_4[0][0]']
#
#  conv4_5_1x1_reduce (Conv2D  (None, 8, 8, 128)            65664     ['conv4_4/relu[0][0]']
#  )
#
#  conv4_5_1x1_reduce_bn (Bat  (None, 8, 8, 128)            512       ['conv4_5_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding12 (ZeroPadding2D)   (None, 12, 12, 128)          0         ['conv4_5_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv4_5_3x3 (Conv2D)        (None, 8, 8, 128)            147584    ['padding12[0][0]']
#
#  conv4_5_3x3_bn (BatchNorma  (None, 8, 8, 128)            512       ['conv4_5_3x3[0][0]']
#  lization)
#
#  conv4_5_1x1_increase (Conv  (None, 8, 8, 512)            66048     ['conv4_5_3x3_bn[0][0]']
#  2D)
#
#  conv4_5_1x1_increase_bn (B  (None, 8, 8, 512)            2048      ['conv4_5_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv4_5 (Add)               (None, 8, 8, 512)            0         ['conv4_5_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv4_4/relu[0][0]']
#
#  conv4_5/relu (Activation)   (None, 8, 8, 512)            0         ['conv4_5[0][0]']
#
#  conv4_6_1x1_reduce (Conv2D  (None, 8, 8, 128)            65664     ['conv4_5/relu[0][0]']
#  )
#
#  conv4_6_1x1_reduce_bn (Bat  (None, 8, 8, 128)            512       ['conv4_6_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding13 (ZeroPadding2D)   (None, 12, 12, 128)          0         ['conv4_6_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv4_6_3x3 (Conv2D)        (None, 8, 8, 128)            147584    ['padding13[0][0]']
#
#  conv4_6_3x3_bn (BatchNorma  (None, 8, 8, 128)            512       ['conv4_6_3x3[0][0]']
#  lization)
#
#  conv4_6_1x1_increase (Conv  (None, 8, 8, 512)            66048     ['conv4_6_3x3_bn[0][0]']
#  2D)
#
#  conv4_6_1x1_increase_bn (B  (None, 8, 8, 512)            2048      ['conv4_6_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv4_6 (Add)               (None, 8, 8, 512)            0         ['conv4_6_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv4_5/relu[0][0]']
#
#  conv4_6/relu (Activation)   (None, 8, 8, 512)            0         ['conv4_6[0][0]']
#
#  conv5_1_1x1_reduce (Conv2D  (None, 8, 8, 256)            131328    ['conv4_6/relu[0][0]']
#  )
#
#  conv5_1_1x1_reduce_bn (Bat  (None, 8, 8, 256)            1024      ['conv5_1_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding14 (ZeroPadding2D)   (None, 16, 16, 256)          0         ['conv5_1_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv5_1_3x3 (Conv2D)        (None, 8, 8, 256)            590080    ['padding14[0][0]']
#
#  conv5_1_3x3_bn (BatchNorma  (None, 8, 8, 256)            1024      ['conv5_1_3x3[0][0]']
#  lization)
#
#  conv5_1_1x1_increase (Conv  (None, 8, 8, 1024)           263168    ['conv5_1_3x3_bn[0][0]']
#  2D)
#
#  conv5_1_1x1_proj (Conv2D)   (None, 8, 8, 1024)           525312    ['conv4_6/relu[0][0]']
#
#  conv5_1_1x1_increase_bn (B  (None, 8, 8, 1024)           4096      ['conv5_1_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv5_1_1x1_proj_bn (Batch  (None, 8, 8, 1024)           4096      ['conv5_1_1x1_proj[0][0]']
#  Normalization)
#
#  conv5_1 (Add)               (None, 8, 8, 1024)           0         ['conv5_1_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv5_1_1x1_proj_bn[0][0]']
#
#  conv5_1/relu (Activation)   (None, 8, 8, 1024)           0         ['conv5_1[0][0]']
#
#  conv5_2_1x1_reduce (Conv2D  (None, 8, 8, 256)            262400    ['conv5_1/relu[0][0]']
#  )
#
#  conv5_2_1x1_reduce_bn (Bat  (None, 8, 8, 256)            1024      ['conv5_2_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding15 (ZeroPadding2D)   (None, 16, 16, 256)          0         ['conv5_2_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv5_2_3x3 (Conv2D)        (None, 8, 8, 256)            590080    ['padding15[0][0]']
#
#  conv5_2_3x3_bn (BatchNorma  (None, 8, 8, 256)            1024      ['conv5_2_3x3[0][0]']
#  lization)
#
#  conv5_2_1x1_increase (Conv  (None, 8, 8, 1024)           263168    ['conv5_2_3x3_bn[0][0]']
#  2D)
#
#  conv5_2_1x1_increase_bn (B  (None, 8, 8, 1024)           4096      ['conv5_2_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv5_2 (Add)               (None, 8, 8, 1024)           0         ['conv5_2_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv5_1/relu[0][0]']
#
#  conv5_2/relu (Activation)   (None, 8, 8, 1024)           0         ['conv5_2[0][0]']
#
#  conv5_3_1x1_reduce (Conv2D  (None, 8, 8, 256)            262400    ['conv5_2/relu[0][0]']
#  )
#
#  conv5_3_1x1_reduce_bn (Bat  (None, 8, 8, 256)            1024      ['conv5_3_1x1_reduce[0][0]']
#  chNormalization)
#
#  padding16 (ZeroPadding2D)   (None, 16, 16, 256)          0         ['conv5_3_1x1_reduce_bn[0][0]'
#                                                                     ]
#
#  conv5_3_3x3 (Conv2D)        (None, 8, 8, 256)            590080    ['padding16[0][0]']
#
#  conv5_3_3x3_bn (BatchNorma  (None, 8, 8, 256)            1024      ['conv5_3_3x3[0][0]']
#  lization)
#
#  conv5_3_1x1_increase (Conv  (None, 8, 8, 1024)           263168    ['conv5_3_3x3_bn[0][0]']
#  2D)
#
#  conv5_3_1x1_increase_bn (B  (None, 8, 8, 1024)           4096      ['conv5_3_1x1_increase[0][0]']
#  atchNormalization)
#
#  conv5_3 (Add)               (None, 8, 8, 1024)           0         ['conv5_3_1x1_increase_bn[0][0
#                                                                     ]',
#                                                                      'conv5_2/relu[0][0]']
#
#  conv5_3/relu (Activation)   (None, 8, 8, 1024)           0         ['conv5_3[0][0]']
#
#  conv5_3_pool1 (AveragePool  (None, 1, 1, 1024)           0         ['conv5_3/relu[0][0]']
#  ing2D)
#
#  conv5_3_pool2 (AveragePool  (None, 2, 2, 1024)           0         ['conv5_3/relu[0][0]']
#  ing2D)
#
#  conv5_3_pool3 (AveragePool  (None, 4, 4, 1024)           0         ['conv5_3/relu[0][0]']
#  ing2D)
#
#  conv5_3_pool6 (AveragePool  (None, 4, 4, 1024)           0         ['conv5_3/relu[0][0]']
#  ing2D)
#
#  conv5_3_pool1_interp (Lamb  (None, 8, 8, 1024)           0         ['conv5_3_pool1[0][0]']
#  da)
#
#  conv5_3_pool2_interp (Lamb  (None, 8, 8, 1024)           0         ['conv5_3_pool2[0][0]']
#  da)
#
#  conv5_3_pool3_interp (Lamb  (None, 8, 8, 1024)           0         ['conv5_3_pool3[0][0]']
#  da)
#
#  conv5_3_pool6_interp (Lamb  (None, 8, 8, 1024)           0         ['conv5_3_pool6[0][0]']
#  da)
#
#  conv5_3_sum (Add)           (None, 8, 8, 1024)           0         ['conv5_3/relu[0][0]',
#                                                                      'conv5_3_pool1_interp[0][0]',
#                                                                      'conv5_3_pool2_interp[0][0]',
#                                                                      'conv5_3_pool3_interp[0][0]',
#                                                                      'conv5_3_pool6_interp[0][0]']
#
#  conv5_4_k1 (Conv2D)         (None, 8, 8, 256)            262400    ['conv5_3_sum[0][0]']
#
#  conv5_4_k1_bn (BatchNormal  (None, 8, 8, 256)            1024      ['conv5_4_k1[0][0]']
#  ization)
#
#  conv5_4_interp (Lambda)     (None, 16, 16, 256)          0         ['conv5_4_k1_bn[0][0]']
#
#  padding17 (ZeroPadding2D)   (None, 20, 20, 256)          0         ['conv5_4_interp[0][0]']
#
#  conv1_sub1 (Conv2D)         (None, 128, 128, 32)         320       ['lambda[0][0]']
#
#  conv_sub4 (Conv2D)          (None, 16, 16, 128)          295040    ['padding17[0][0]']
#
#  conv3_1_sub2_proj (Conv2D)  (None, 16, 16, 128)          32896     ['conv3_1/relu[0][0]']
#
#  conv1_sub1_bn (BatchNormal  (None, 128, 128, 32)         128       ['conv1_sub1[0][0]']
#  ization)
#
#  conv_sub4_bn (BatchNormali  (None, 16, 16, 128)          512       ['conv_sub4[0][0]']
#  zation)
#
#  conv3_1_sub2_proj_bn (Batc  (None, 16, 16, 128)          512       ['conv3_1_sub2_proj[0][0]']
#  hNormalization)
#
#  conv2_sub1 (Conv2D)         (None, 64, 64, 32)           9248      ['conv1_sub1_bn[0][0]']
#
#  sub24_sum (Add)             (None, 16, 16, 128)          0         ['conv_sub4_bn[0][0]',
#                                                                      'conv3_1_sub2_proj_bn[0][0]']
#
#  conv2_sub1_bn (BatchNormal  (None, 64, 64, 32)           128       ['conv2_sub1[0][0]']
#  ization)
#
#  sub24_sum/relu (Activation  (None, 16, 16, 128)          0         ['sub24_sum[0][0]']
#  )
#
#  conv3_sub1 (Conv2D)         (None, 32, 32, 64)           18496     ['conv2_sub1_bn[0][0]']
#
#  sub24_sum_interp (Lambda)   (None, 32, 32, 128)          0         ['sub24_sum/relu[0][0]']
#
#  conv3_sub1_bn (BatchNormal  (None, 32, 32, 64)           256       ['conv3_sub1[0][0]']
#  ization)
#
#  padding18 (ZeroPadding2D)   (None, 36, 36, 128)          0         ['sub24_sum_interp[0][0]']
#
#  conv3_sub1_proj (Conv2D)    (None, 32, 32, 128)          8320      ['conv3_sub1_bn[0][0]']
#
#  conv_sub2 (Conv2D)          (None, 32, 32, 128)          147584    ['padding18[0][0]']
#
#  conv3_sub1_proj_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_sub1_proj[0][0]']
#  ormalization)
#
#  conv_sub2_bn (BatchNormali  (None, 32, 32, 128)          512       ['conv_sub2[0][0]']
#  zation)
#
#  sub12_sum (Add)             (None, 32, 32, 128)          0         ['conv3_sub1_proj_bn[0][0]',
#                                                                      'conv_sub2_bn[0][0]']
#
#  sub12_sum/relu (Activation  (None, 32, 32, 128)          0         ['sub12_sum[0][0]']
#  )
#
#  sub12_sum_interp (Lambda)   (None, 64, 64, 128)          0         ['sub12_sum/relu[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 256, 256, 128)        0         ['sub12_sum_interp[0][0]']
#  D)
#
#  conv6_cls (Conv2D)          (None, 256, 256, 1)          129       ['up_sampling2d[0][0]']
#
# ==================================================================================================
# Total params: 6739329 (25.71 MB)
# Trainable params: 6710785 (25.60 MB)
# Non-trainable params: 28544 (111.50 KB)
# __________________________________________________________________________________________________

# %%
earlystopper = EarlyStopping(patience=50, verbose=1)
checkpointer = ModelCheckpoint('model-ICNet-initial.h5', verbose=1, save_best_only=True)

# %%
results = model.fit(X_train, Y_train, validation_split=0.2, batch_size=16, epochs=300, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 results = model.fit(X_train, Y_train, validation_split=0.2, batch_size=16, epochs=400,
#       2                     callbacks=[earlystopper, checkpointer])
#
# File ~\AppData\Roaming\Python\Python38\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:890, in Function._call(self, *args, **kwds)
#     886     pass  # Fall through to cond-based initialization.
#     887   else:
#     888     # Lifting succeeded, so variables are initialized and we can run the
#     889     # no_variable_creation function.
# --> 890     return self._no_variable_creation_fn(*args, **kwds)
#     891 else:
#     892   _, _, filtered_flat_args = (
#     893       self._variable_creation_fn._function_spec  # pylint: disable=protected-access
#     894       .canonicalize_function_inputs(
#     895           args, kwds))
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save_weights("model-ICNet-trained.h5", overwrite=True)
model.save("model-ICNet-trained-model.h5", overwrite=True)

# %%
model = load_model('model-ICNet-trained-model.h5')
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 45/45 [==============================] - 1s 21ms/sample
# 6/6 [==============================] - 0s 3ms/sample
# 30/30 [==============================] - 0s 2ms/sample

# %%
ix = random.randint(0, len(preds_train_t))
imshow(np.squeeze(X_train[ix]))
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
ix = random.randint(0, len(preds_val_t)-1)
print(len(preds_val_t))
print(ix)
imshow(np.squeeze(X_train[int(X_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# 6
# 3
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
ix = random.randint(0, len(preds_val_t))
imshow(np.squeeze(X_test[ix]))
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# Denormalizing the output segmentation map

# %%
preds_test_t[ix] = (preds_test_t[ix] + 127.5) * 255

# %%
preds_test_t[ix].shape
# Out:
# (256, 256, 1)

# %%
import cv2
backtorgb = cv2.cvtColor(preds_test_t[ix],cv2.COLOR_GRAY2RGB)

# %%
plt.imshow(backtorgb)

# %%
# %matplotlib inline
img = cv2.addWeighted(X_test[ix], 1, preds_test_t[ix], 0.8, 0)
plt.imshow(img, cmap='gray')
